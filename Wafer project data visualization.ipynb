# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.impute import KNNImputer
# %matplotlib inline

# %%
df=pd.read_csv('input_file.csv')
df
# Out:
#      Wafer  Sensor_1  Sensor_2  Sensor_3  Sensor_4  Sensor_5  Sensor_6  \
# 0     1201   3045.98   2544.85   2253.34   1873.87    1.1691     100.0
# 1     1202   3151.98   2563.75   2175.26   1022.17    1.2833     100.0
# 2     1203   3071.18   2489.86   2195.30   1151.82    0.9220     100.0
# 3     1204   2958.46   2523.78   2171.86   1156.60    1.4025     100.0
# 4     1205   3196.21   2413.39   2255.52   1763.07    1.2226     100.0
# ..     ...       ...       ...       ...       ...       ...       ...
# 832   1396   3169.00   2265.60   2187.99   1096.38    0.9065     100.0
# 833   1397   2923.19   2516.40   2180.89   1084.72    0.9085     100.0
# 834   1398   3003.43   2448.34   2205.50   1287.35    2.3842     100.0
# 835   1399   2953.63   2500.05   2195.98   1388.29    1.5605     100.0
# 836   1400   3034.74   2458.90   2192.19   1435.96    2.3870     100.0
#
#      Sensor_7  Sensor_8  Sensor_9  ...  Sensor_582  Sensor_583  Sensor_584  \
# 0     94.9722    0.1210    1.4752  ...         NaN      0.4948      0.0123
# 1    100.6220    0.1250    1.4536  ...         NaN      0.5063      0.0113
# 2    103.5470    0.1232    1.4826  ...         NaN      0.5033      0.0112
# 3    100.1370    0.1243    1.4645  ...         NaN      0.4954      0.0136
# 4    101.5880    0.1200    1.4845  ...    353.8320      0.5058      0.0094
# ..        ...       ...       ...  ...         ...         ...         ...
# 832   97.6567    0.1221    1.4109  ...     73.6335      0.4912      0.0127
# 833   94.2467    0.1226    1.3137  ...         NaN      0.4939      0.0163
# 834  111.7640    0.1241    1.4339  ...         NaN      0.4966      0.0084
# 835  103.2400    0.1234    1.5177  ...    171.3180      0.5009      0.0135
# 836  107.3990    0.1229    1.5447  ...    368.8940      0.5008      0.0137
#
#      Sensor_585  Sensor_586  Sensor_587  Sensor_588  Sensor_589  Sensor_590  \
# 0        0.0033      2.4804      0.0291      0.0102      0.0033     35.0279
# 1        0.0031      2.2284      0.0291      0.0102      0.0033     35.0279
# 2        0.0029      2.2320      0.0291      0.0102      0.0033     35.0279
# 3        0.0033      2.7511      0.0291      0.0102      0.0033     35.0279
# 4        0.0026      1.8673      0.0053      0.0188      0.0057    353.8320
# ..          ...         ...         ...         ...         ...         ...
# 832      0.0039      2.5801      0.0166      0.0122      0.0036     73.6335
# 833      0.0037      3.2914      0.0166      0.0122      0.0036     73.6335
# 834      0.0020      1.6866      0.0166      0.0122      0.0036     73.6335
# 835      0.0035      2.7038      0.0178      0.0305      0.0106    171.3180
# 836      0.0033      2.7317      0.0048      0.0178      0.0055    368.8940
#
#      Output
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1
# ..      ...
# 832      -1
# 833      -1
# 834      -1
# 835      -1
# 836      -1
#
# [837 rows x 592 columns]

# %%
knn=KNNImputer()
df1=knn.fit_transform(df)
df1=pd.DataFrame(df1, columns=df.columns)

# %%
df1
# Out:
#       Wafer  Sensor_1  Sensor_2  Sensor_3  Sensor_4  Sensor_5  Sensor_6  \
# 0    1201.0   3045.98   2544.85   2253.34   1873.87    1.1691     100.0
# 1    1202.0   3151.98   2563.75   2175.26   1022.17    1.2833     100.0
# 2    1203.0   3071.18   2489.86   2195.30   1151.82    0.9220     100.0
# 3    1204.0   2958.46   2523.78   2171.86   1156.60    1.4025     100.0
# 4    1205.0   3196.21   2413.39   2255.52   1763.07    1.2226     100.0
# ..      ...       ...       ...       ...       ...       ...       ...
# 832  1396.0   3169.00   2265.60   2187.99   1096.38    0.9065     100.0
# 833  1397.0   2923.19   2516.40   2180.89   1084.72    0.9085     100.0
# 834  1398.0   3003.43   2448.34   2205.50   1287.35    2.3842     100.0
# 835  1399.0   2953.63   2500.05   2195.98   1388.29    1.5605     100.0
# 836  1400.0   3034.74   2458.90   2192.19   1435.96    2.3870     100.0
#
#      Sensor_7  Sensor_8  Sensor_9  ...  Sensor_582  Sensor_583  Sensor_584  \
# 0     94.9722    0.1210    1.4752  ...    52.96994      0.4948      0.0123
# 1    100.6220    0.1250    1.4536  ...    93.82920      0.5063      0.0113
# 2    103.5470    0.1232    1.4826  ...    68.32616      0.5033      0.0112
# 3    100.1370    0.1243    1.4645  ...    36.75696      0.4954      0.0136
# 4    101.5880    0.1200    1.4845  ...   353.83200      0.5058      0.0094
# ..        ...       ...       ...  ...         ...         ...         ...
# 832   97.6567    0.1221    1.4109  ...    73.63350      0.4912      0.0127
# 833   94.2467    0.1226    1.3137  ...    62.40120      0.4939      0.0163
# 834  111.7640    0.1241    1.4339  ...    78.08556      0.4966      0.0084
# 835  103.2400    0.1234    1.5177  ...   171.31800      0.5009      0.0135
# 836  107.3990    0.1229    1.5447  ...   368.89400      0.5008      0.0137
#
#      Sensor_585  Sensor_586  Sensor_587  Sensor_588  Sensor_589  Sensor_590  \
# 0        0.0033      2.4804      0.0291      0.0102      0.0033     35.0279
# 1        0.0031      2.2284      0.0291      0.0102      0.0033     35.0279
# 2        0.0029      2.2320      0.0291      0.0102      0.0033     35.0279
# 3        0.0033      2.7511      0.0291      0.0102      0.0033     35.0279
# 4        0.0026      1.8673      0.0053      0.0188      0.0057    353.8320
# ..          ...         ...         ...         ...         ...         ...
# 832      0.0039      2.5801      0.0166      0.0122      0.0036     73.6335
# 833      0.0037      3.2914      0.0166      0.0122      0.0036     73.6335
# 834      0.0020      1.6866      0.0166      0.0122      0.0036     73.6335
# 835      0.0035      2.7038      0.0178      0.0305      0.0106    171.3180
# 836      0.0033      2.7317      0.0048      0.0178      0.0055    368.8940
#
#      Output
# 0      -1.0
# 1      -1.0
# 2      -1.0
# 3      -1.0
# 4      -1.0
# ..      ...
# 832    -1.0
# 833    -1.0
# 834    -1.0
# 835    -1.0
# 836    -1.0
#
# [837 rows x 592 columns]

# %%
pca=PCA(n_components=2)

# %%
x=pca.fit_transform(df1.drop(columns='Wafer'))
x
# Out:
# array([[-6551.66597544,  -680.23894919],
#        [-2086.90346779,  7119.15330065],
#        [-1903.10458134, -1827.8394186 ],
#        ...,
#        [-5598.85247252,  6078.91173896],
#        [-2581.80387603, -2218.78161676],
#        [11118.64906086,  9412.0999167 ]])

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=x)
# Out:
# <AxesSubplot:>
